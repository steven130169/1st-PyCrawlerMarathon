# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# rl":"https://api.github.com/repos/CodeForPoznan/pah-fm/subscribers","subscription_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/subscription","commits_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/commits{/sha}","git_commits_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/git/commits{/sha}","comments_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/comments{/number}","issue_comment_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/issues/comments{/number}","contents_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/contents/{+path}","compare_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/compare/{base}...{head}","merges_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/merges","archive_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/downloads","issues_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/issues{/number}","pulls_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/pulls{/number}","milestones_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/milestones{/number}","notifications_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/labels{/name}","releases_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/releases{/id}","deployments_url":"https://api.github.com/repos/CodeForPoznan/pah-fm/deployments","created_at":"2018-10-08T14:40:38Z","updated_at":"2020-02-26T14:20:08Z","pushed_at":"2020-02-28T11:08:56Z","git_url":"git://github.com/CodeForPoznan/pah-fm.git","ssh_url":"git@github.com:CodeForPoznan/pah-fm.git","clone_url":"https://github.com/CodeForPoznan/pah-fm.git","svn_url":"https://github.com/CodeForPoznan/pah-fm","homepage":null,"size":1577,"stargazers_count":5,"watchers_count":5,"language":"Python","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"forks_count":36,"mirror_url":null,"archived":false,"disabled":false,"open_issues_count":35,"license":null,"forks":36,"open_issues":35,"watchers":5,"default_branch":"develop"}},"_links":{"self":{"href":"https://api.github.com/repos/CodeForPoznan/pah-fm/pulls/441"},"html":{"href":"https://github.com/CodeForPoznan/pah-fm/pull/441"},"issue":{"href":"https://api.github.com/repos/CodeForPoznan/pah-fm/issues/441"},"comments":{"href":"https://api.github.com/repos/CodeForPoznan/pah-fm/issues/441/comments"},"review_comments":{"href":"https://api.github.com/repos/CodeForPoznan/pah-fm/pulls/441/comments"},"review_comment":{"href":"https://api.github.com/repos/CodeForPoznan/pah-fm/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/CodeForPoznan/pah-fm/pulls/441/commits"},"statuses":{"href":"https://api.github.com/repos/CodeForPoznan/pah-fm/statuses/febbdd922187b37cca97e64d23b6a928c2b92558"}},"author_association":"CONTRIBUTOR","merged":false,"mergeable":null,"rebaseable":null,"mergeable_state":"unknown","merged_by":null,"comments":0,"review_comments":0,"maintainer_can_modify":true,"commits":1,"additions":44,"deletions":1,"changed_files":2}},"public":true,"created_at":"2020-02-29T12:59:00Z","org":{"id":22869943,"login":"CodeForPoznan","gravatar_id":"","url":"https://api.github.com/orgs/CodeForPoznan","avatar_url":"https://avatars.githubusercontent.com/u/22869943?"}},{"id":"11643339981","type":"IssuesEvent","actor":{"id":30082422,"login":"adguard-bot","display_login":"adguard-bot","gravatar_id":"","url":"https://api.github.com/users/adguard-bot","avatar_url":"https://avatars.githubusercontent.com/u/30082422?"},"repo":{"id":22637619,"name":"AdguardTeam/AdguardFilters","url":"https://api.github.com/repos/AdguardTeam/AdguardFilters"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/AdguardTeam/AdguardFilters/issues/50711","repository_url":"https://api.github.com/repos/AdguardTeam/AdguardFilters","labels_url":"https ...

# %%
import json

json.loads(r.text)
# Out:
#     'archived': False,
#       'disabled': False,
#       'open_issues_count': 35,
#       'license': None,
#       'forks': 36,
#       'open_issues': 35,
#       'watchers': 5,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/CodeForPoznan/pah-fm/pulls/441'},
#      'html': {'href': 'https://github.com/CodeForPoznan/pah-fm/pull/441'},
#      'issue': {'href': 'https://api.github.com/repos/CodeForPoznan/pah-fm/issues/441'},
#      'comments': {'href': 'https://api.github.com/repos/CodeForPoznan/pah-fm/issues/441/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/CodeForPoznan/pah-fm/pulls/441/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/CodeForPoznan/pah-fm/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/CodeForPoznan/pah-fm/pulls/441/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/CodeForPoznan/pah-fm/statuses/febbdd922187b37cca97e64d23b6a928c2b92558'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 44,
#     'deletions': 1,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2020-02-29T12:59:00Z',
#   'org': {'id': 22869943,
#    'login': 'CodeForPoznan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CodeForPoznan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22869943?'}},
#  {'id': '11643339981',
#   'type': 'IssuesEvent',
#   'actor': {'id': 30082422,
#    'login': 'adguard-bot',
#    'display_login': 'adguard-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adguard-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30082422?'},
#   'repo': {'id': 22637619,
#    'name': 'AdguardTeam/AdguardFilters',
#    'url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/issues/50711',
#     'repository_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters',
#     'labels_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/issues/50711/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/issues/50711/comments',
#     'events_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/issues/50711/events',
#     'html_url': 'https://github.com/AdguardTeam/AdguardFilters/issues/50711',
#     'id': 573289985,
#     'node_id': 'MDU6SXNzdWU1NzMyODk5ODU=',
#     'number': 50711,
#     'title': 'youtube.com',
#     'user': {'login': 'adguard-bot',
#      'id': 30082422,
#      'node_id': 'MDQ6VXNlcjMwMDgyNDIy',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/30082422?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/adguard-bot',
#      'html_url': 'https://github.com/adguard-bot',
#      'followers_url': 'https://api.github.com/users/adguard-bot/followers',
#      'following_url': 'https://api.github.com/users/adguard-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/adguard-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/adguard-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/adguard-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/adguard-bot/orgs',
#      'repos_url': 'https://api.github.com/users/adguard-bot/repos',
#      'events_url': 'https://api.github.com/users/adguard-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/adguard-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 766811254,
#       'node_id': 'MDU6TGFiZWw3NjY4MTEyNTQ=',
#       'url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/labels/N:%20AdGuard%20Browser%20Extension',
#       'name': 'N: AdGuard Browser Extension',
#       'color': 'b6d7a8',
#       'default': False,
#       'description': None},
#      {'id': 745624291,
#       'node_id': 'MDU6TGFiZWw3NDU2MjQyOTE=',
#       'url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/labels/P1:%20Critical',
#       'name': 'P1: Critical',
#       'color': '930000',
#       'default': False,
#       'description': None},
#      {'id': 252425980,
#       'node_id': 'MDU6TGFiZWwyNTI0MjU5ODA=',
#       'url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/labels/T:%20Incorrect%20Blocking',
#       'name': 'T: Incorrect Blocking',
#       'color': 'ff0000',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-02-29T12:59:00Z',
#     'updated_at': '2020-02-29T12:59:00Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '\n### Issue URL (Incorrect Blocking)\n [https://www.youtube.com/watch?v=t29rGc-wWYg&list=LLjGd4Di8cJhDH-ftI0wDAUw&index=4](https://adguardteam.github.io/AnonymousRedirect/redirect.html?url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3Dt29rGc-wWYg%26list%3DLLjGd4Di8cJhDH-ftI0wDAUw%26index%3D4)\n### Comment\n> Podczas włączonego blokera na Youtube wyskakują czasami błędy.\n\n### Screenshots\n<details>\n  <summary>Screenshot 1</summary>\n\n  ![Screenshot 1](https://reports-img.adguard.com/v3n1EGj.png)\n</details>\n<details>\n  <summary>Screenshot 2</summary>\n\n  ![Screenshot 2](https://reports-img.adguard.com/4806GTo.png)\n</details>\n\n### System configuration\n\nInformation | value\n--- | ---\nPlatform: | Ext\nAdGuard version: | 3.3.8\nBrowser: | Chrome\nFilters: | <b>Ad Blocking:</b><br/> AdGuard Base<br/><br/><b>Other:</b><br/> Filter unblocking search ads and self-promotion<br/><br/><b>Language-specific:</b><br/> Official Polish filters for AdBlock, uBlock Origin & AdGuard\nOther extensions used: | brak'}},
#   'public': True,
#   'created_at': '2020-02-29T12:59:00Z',
#   'org': {'id': 8361145,
#    'login': 'AdguardTeam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/AdguardTeam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8361145?'}},
#  {'id': '11643339976',
#   'type': 'PushEvent',
#   'actor': {'id': 16778484,
#    'login': 'jose-moran',
#    'display_login': 'jose-moran',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jose-moran',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16778484?'},
#   'repo': {'id': 243967065,
#    'name': 'jose-moran/NAEC',
#    'url': 'https://api.github.com/repos/jose-moran/NAEC'},
#   'payload': {'push_id': 4699471972,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5aa72e8d21f2015422b3fd809c2ad5190bf110f0',
#    'before': '19cb28d9e56974f28696b18c9c510c03b2bdac47',
#    'commits': [{'sha': '5aa72e8d21f2015422b3fd809c2ad5190bf110f0',
#      'author': {'email': 'jose.moran@polytechnique.edu', 'name': 'Jose Moran'},
#      'message': 'Fixed readme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jose-moran/NAEC/commits/5aa72e8d21f2015422b3fd809c2ad5190bf110f0'}]},
#   'public': True,
#   'created_at': '2020-02-29T12:59:00Z'},
#  {'id': '11643339969',
#   'type': 'PushEvent',
#   'actor': {'id': 61194034,
#    'login': 'xiaoxiana',
#    'display_login': 'xiaoxiana',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xiaoxiana',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61194034?'},
#   'repo': {'id': 243962696,
#    'name': 'xiaoxiana/yqt',
#    'url': 'https://api.github.com/repos/xiaoxiana/yqt'},
#   'payload': {'push_id': 4699471969,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fd3591d6756c3c4f23c50cf5b608deb5909a844a',
#    'before': '6eb0280d38ed3564ec0629c43af8cc990c39978f',
#    'commits': [{'sha': 'fd3591d6756c3c4f23c50cf5b608deb5909a844a',
#      'author': {'email': '2279251678@qq.com', 'name': '小白'},
#      'message': 'first commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xiaoxiana/yqt/commits/fd3591d6756c3c4f23c50cf5b608deb5909a844a'}]},
#   'public': True,
#   'created_at': '2020-02-29T12:59:00Z'},
#  {'id': '11643339973',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 59019740,
#    'login': 'josepbbs',
#    'display_login': 'josepbbs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/josepbbs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59019740?'},
#   'repo': {'id': 10590419,
#    'name': 'noitcudni/google-search-console-bulk-url-removal',
#    'url': 'https://api.github.com/repos/noitcudni/google-search-console-bulk-url-removal'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/noitcudni/google-search-console-bulk-url-removal/issues/56',
#     'repository_url': 'https://api.github.com/repos/noitcudni/google-search-console-bulk-url-removal',
#     'labels_url': 'https://api.github.com/repos/noitcudni/google-search-console-bulk-url-removal/issues/56/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/noitcudni/google-search-console-bulk-url-removal/issues/56/comments',
#     'events_url': 'https://api.github.com/repos/noitcudni/google-search-console-bulk-url-removal/issues/56/events',
#     'html_url': 'https://github.com/noitcudni/google-search-console-bulk-url-removal/issues/56',
#     'id': 571441498,
#     'node_id': 'MDU6SXNzdWU1NzE0NDE0OTg=',
#     'number': 56,
#     'title': '500 when clicking on the removal tab',
#     'user': {'login': 'noitcudni',
#      'id': 78951,
#      'node_id': 'MDQ6VXNlcjc4OTUx',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/78951?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/noitcudni',
#      'html_url': 'https://github.com/noitcudni',
#      'followers_url': 'https://api.github.com/users/noitcudni/followers',
#      'following_url': 'https://api.github.com/users/noitcudni/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/noitcudni/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/noitcudni/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/noitcudni/subscriptions',
#      'organizations_url': 'https://api.github.com/users/noitcudni/orgs',
#      'repos_url': 'https://api.github.com/users/noitcudni/repos',
#      'events_url': 'https://api.github.com/users/noitcudni/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/noitcudni/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 9,
#     'created_at': '2020-02-26T14:52:08Z',
#     'updated_at': '2020-02-29T12:59:00Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'body': '> @josepbbs, you\'ll need to select a "property" on the left-hand pane. Also, the "Submit CSV file" button is inside the extension popup. You need to click on the green trash can icon.\r\n\r\nthanks for your answer @noitcudni \r\nI managed to see the green trash icon, it had disabled itself due to unknow reason\r\nnow the problem is that when I clock on the removal link on the left panel it shows this strange error\r\n\r\n> _500. That’s an error.\r\n> \r\n> There was an error. Please try again later. That’s all we know._\r\n\r\ntested on chrome and firefox browser and selecting the right property...\r\n\r\ndoes somebody have this error too?\r\n\r\nany ideas?\r\n\r\n_Originally posted by @josepbbs in https://github.com/noitcudni/google-search-console-bulk-url-removal/issues/54#issuecomment-591092954_'},
#    'comment': {'url': 'https://api.github.com/repos/noitcudni/google-search-console-bulk-url-removal/issues/comments/592942991',
#     'html_url': 'https://github.com/noitcudni/google-search-console-bulk-url-removal/issues/56#issuecomment-592942991',
#     'issue_url': 'https://api.github.com/repos/noitcudni/google-search-console-bulk-url-removal/issues/56',
#     'id': 592942991,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5Mjk0Mjk5MQ==',
#     'user': {'login': 'josepbbs',
#      'id': 59019740,
#      'node_id': 'MDQ6VXNlcjU5MDE5NzQw',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/59019740?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/josepbbs',
#      'html_url': 'https://github.com/josepbbs',
#      'followers_url': 'https://api.github.com/users/josepbbs/followers',
#      'following_url': 'https://api.github.com/users/josepbbs/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/josepbbs/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/josepbbs/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/josepbbs/subscriptions',
#      'organizations_url': 'https://api.github.com/users/josepbbs/orgs',
#      'repos_url': 'https://api.github.com/users/josepbbs/repos',
#      'events_url': 'https://api.github.com/users/josepbbs/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/josepbbs/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-02-29T12:59:00Z',
#     'updated_at': '2020-02-29T12:59:00Z',
#     'author_association': 'NONE',
#     'body': "Today the remolvals section started aparently to work normally without doing anything else special\r\nDon't know what might have happened, but I hope it keeps working normally, so you can close the topic at the moment\r\nthanks"}},
#   'public': True,
#   'created_at': '2020-02-29T12:59:00Z'},
#  {'id': '11643339968',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 57052760,
#    'login': 'sourdurian',
#    'display_login': 'sourdurian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sourdurian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57052760?'},
#   'repo': {'id': 239201565,
#    'name': 'serengil/deepface',
#    'url': 'https://api.github.com/repos/serengil/deepface'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/serengil/deepface/issues/5',
#     'repository_url': 'https://api.github.com/repos/serengil/deepface',
#     'labels_url': 'https://api.github.com/repos/serengil/deepface/issues/5/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/serengil/deepface/issues/5/comments',
#     'events_url': 'https://api.github.com/repos/serengil/deepface/issues/5/events',
#     'html_url': 'https://github.com/serengil/deepface/issues/5',
#     'id': 572791620,
#     'node_id': 'MDU6SXNzdWU1NzI3OTE2MjA=',
#     'number': 5,
#     'title': 'Cannot import name deepface',
#     'user': {'login': 'sourdurian',
#      'id': 57052760,
#      'node_id': 'MDQ6VXNlcjU3MDUyNzYw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/57052760?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sourdurian',
#      'html_url': 'https://github.com/sourdurian',
#      'followers_url': 'https://api.github.com/users/sourdurian/followers',
#      'following_url': 'https://api.github.com/users/sourdurian/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sourdurian/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sourdurian/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sourdurian/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sourdurian/orgs',
#      'repos_url': 'https://api.github.com/users/sourdurian/repos',
#      'events_url': 'https://api.github.com/users/sourdurian/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sourdurian/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2020-02-28T14:30:45Z',
#     'updated_at': '2020-02-29T12:59:00Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "Hi there! \r\n\r\nI have ran into a similar issue as the previous guy and have also did the same things. But i'm running on Mac OS. \r\n\r\nImportError: cannot import name 'DeepFace' from 'deepface' (/Users/oha/anaconda3/lib/python3.7/site-packages/deepface/__init__.py)\r\n\r\n```\r\n!pip install deepface\r\nfrom deepface import DeepFace\r\nimport cv2\r\nimport matplotlib.pyplot as plt\r\nfrom tensorflow import keras\r\n\r\nRequirement already satisfied: deepface in /Users/oha/anaconda3/lib/python3.7/site-packages (0.0.9)\r\nRequirement already satisfied: gdown>=3.10.1 in /Users/oha/anaconda3/lib/python3.7/site-packages (from deepface) (3.10.1)\r\n```\r\n\r\nAny idea how to fix this? \r\n\r\nThanks! \r\n"},
#    'comment': {'url': 'https://api.github.com/repos/serengil/deepface/issues/comments/592942990',
#     'html_url': 'https://github.com/serengil/deepface/issues/5#issuecomment-592942990',
#     'issue_url': 'https://api.github.com/repos/serengil/deepface/issues/5',
#     'id': 592942990,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5Mjk0Mjk5MA==',
#     'user': {'login': 'sourdurian',
#      'id': 57052760,
#      'node_id': 'MDQ6VXNlcjU3MDUyNzYw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/57052760?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sourdurian',
#      'html_url': 'https://github.com/sourdurian',
#      'followers_url': 'https://api.github.com/users/sourdurian/followers',
#      'following_url': 'https://api.github.com/users/sourdurian/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sourdurian/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sourdurian/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sourdurian/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sourdurian/orgs',
#      'repos_url': 'https://api.github.com/users/sourdurian/repos',
#      'events_url': 'https://api.github.com/users/sourdurian/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sourdurian/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-02-29T12:59:00Z',
#     'updated_at': '2020-02-29T12:59:00Z',
#     'author_association': 'NONE',
#     'body': 'Also, i went into the DeepFace.py file and saw the first few lines of code \r\n\r\n```\r\nfrom deepface.basemodels import VGGFace, OpenFace, Facenet, FbDeepFace\r\nfrom deepface.extendedmodels import Age, Gender, Race, Emotion\r\n```\r\n\r\nI dont see any DeepFace module thats why maybe executing ```from deepface import DeepFace``` is not working? '}},
#   'public': True,
#   'created_at': '2020-02-29T12:59:00Z'},
#  {'id': '11643339958',
#   'type': 'WatchEvent',
#   'actor': {'id': 1535751,
#    'login': 'ghostlevel',
#    'display_login': 'ghostlevel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ghostlevel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1535751?'},
#   'repo': {'id': 87705200,
#    'name': 'amanusk/s-tui',
#    'url': 'https://api.github.com/repos/amanusk/s-tui'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-29T12:59:00Z'},
#  {'id': '11643339956',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46632135,
#    'name': 'Lombiq/Orchard-Token-Title',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Token-Title'},
#   'payload': {'push_id': 4699471962,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '25f574f745a71eada29ea5d4f8286496b236ca0a',
#    'before': '25f574f745a71eada29ea5d4f8286496b236ca0a',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-02-29T12:59:00Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e5a614b-30e91aa2333a6eb483648522'},
#  'origin': '180.218.169.200',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e5a614c-18afee740d1eec5afcaecdc6'},
#  'json': None,
#  'origin': '180.218.169.200',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e5a614d-3f3bb01ff564d436c84d0e3c'},
#  'json': None,
#  'origin': '180.218.169.200',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
